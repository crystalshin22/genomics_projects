# %% [markdown]
# # Prostate Cancer Risk Screening Using Germline Variant Data

# %%
# !pip install scikit-allel
# !pip install zarr
# Out:
# Collecting scikit-allel
#   Downloading scikit_allel-1.3.5-cp38-cp38-macosx_10_9_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from scikit-allel) (1.19.2)
# Requirement already satisfied: dask[array] in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from scikit-allel) (2.30.0)
# Requirement already satisfied: pyyaml in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->scikit-allel) (5.3.1)
# Requirement already satisfied: toolz>=0.8.2 in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->scikit-allel) (0.11.1)
# Installing collected packages: scikit-allel
# Successfully installed scikit-allel-1.3.5
# WARNING: You are using pip version 21.0.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/crystalshin/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Collecting zarr
#   Downloading zarr-2.13.3-py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 10.3 MB/s eta 0:00:01
# Collecting fasteners
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Collecting numcodecs>=0.10.0
#   Downloading numcodecs-0.11.0-cp38-cp38-macosx_10_9_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 9.7 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.7 in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from zarr) (1.19.2)
# Collecting asciitree
#   Downloading asciitree-0.3.3.tar.gz (4.0 kB)
# Requirement already satisfied: entrypoints in /Users/crystalshin/opt/anaconda3/lib/python3.8/site-packages (from numcodecs>=0.10.0->zarr) (0.3)
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5035 sha256=cad9ecd67baa7eaf1946cd4a7b127b564a18cbcc6a8817d04858f7eebdd8876d
#   Stored in directory: /Users/crystalshin/Library/Caches/pip/wheels/a3/d7/75/19cd0d2a893cad4bb0b2b16dd572ad2916d19c0d5ee9612511
# Successfully built asciitree
# Installing collected packages: numcodecs, fasteners, asciitree, zarr
# Successfully installed asciitree-0.3.3 fasteners-0.18 numcodecs-0.11.0 zarr-2.13.3
# WARNING: You are using pip version 21.0.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/crystalshin/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import os

cwd = os.getcwd()
DATA = cwd + '/data'

# %% [markdown]
# ## Identifying Pathogenic Variants

# %% [markdown]
# We can identify potential disease-causing variants using germline variant data. 'Clinvar' is a clinical variants database for pathogenic disease variant annotation. In this analysis, I will identify pathogenic germline variants that are likely to result in prostate cancer in 1000 genome project subjects. 1000 genome project contains variants from whole genome sequencing of 2,504 volunteers of 26 sub-population. I have downloaded the Clinvar database as a VCF file. VCF (variant call format) is the summary of all variants compared to the reference genome, and each row contains the annotation for each variant. We are using variant mapped to human reference genome version GRCh37 since the 1000 genome database is also mapped to the same version.

# %%
import allel
import numpy as np
import sys

clinvar_file = DATA + "/clinvar_20220910_grch37.vcf.gz"
clinvar = allel.read_vcf(str(clinvar_file), fields="*", log=sys.stdout)
# Out:
# [read_vcf] 65536 rows in 0.66s; chunk in 0.66s (98744 rows/s); 1:150469297
# [read_vcf] 131072 rows in 1.31s; chunk in 0.65s (100707 rows/s); 2:26467440
# [read_vcf] 196608 rows in 1.97s; chunk in 0.66s (99585 rows/s); 2:165946783
# [read_vcf] 262144 rows in 2.66s; chunk in 0.69s (95524 rows/s); 2:233113958
# [read_vcf] 327680 rows in 3.35s; chunk in 0.69s (94696 rows/s); 3:128627919
# [read_vcf] 393216 rows in 4.03s; chunk in 0.68s (96557 rows/s); 4:184615101
# [read_vcf] 458752 rows in 4.66s; chunk in 0.63s (103692 rows/s); 5:148377020
# [read_vcf] 524288 rows in 5.33s; chunk in 0.67s (97701 rows/s); 6:129774241
# [read_vcf] 589824 rows in 5.97s; chunk in 0.64s (102314 rows/s); 7:124532342
# [read_vcf] 655360 rows in 6.66s; chunk in 0.68s (95891 rows/s); 8:145739033
# [read_vcf] 720896 rows in 7.28s; chunk in 0.62s (105669 rows/s); 9:139418044
# [read_vcf] 786432 rows in 7.88s; chunk in 0.60s (108906 rows/s); 11:3877646
# [read_vcf] 851968 rows in 8.52s; chunk in 0.65s (101525 rows/s); 11:108218000
# [read_vcf] 917504 rows in 9.16s; chunk in 0.64s (102565 rows/s); 12:112892622
# [read_vcf] 983040 rows in 9.81s; chunk in 0.65s (101412 rows/s); 14:64457839
# [read_vcf] 1048576 rows in 10.45s; chunk in 0.64s (101987 rows/s); 15:80465343
# [read_vcf] 1114112 rows in 11.12s; chunk in 0.66s (98663 rows/s); 16:56899006
# [read_vcf] 1179648 rows in 11.83s; chunk in 0.71s (91703 rows/s); 17:33446172
# [read_vcf] 1245184 rows in 12.52s; chunk in 0.69s (95209 rows/s); 18:19070202
# [read_vcf] 1310720 rows in 13.17s; chunk in 0.65s (100337 rows/s); 19:39061277
# [read_vcf] 1376256 rows in 13.80s; chunk in 0.62s (105143 rows/s); 21:46929440
# [read_vcf] 1441792 rows in 14.48s; chunk in 0.68s (96189 rows/s); X:70329122
# [read_vcf] 1475077 rows in 14.83s; chunk in 0.35s (94499 rows/s)
# [read_vcf] all done (99469 rows/s)

# %% [markdown]
# Now, we would like to find all variants that are annotated as pathogenic. For more thorough search in real life, we would want to search all chromosomes for pathogenic variants, but for simplicity of this analysis, we will restrict the boundary to chromosome X.
#
# Pathogenicity can be found in column variants/CLNSIG, and the disease name could be found in variants/CLNDN. I used regular expression to find all entries containing the word "Pathogenic" in the column `variants/CLNDN`.

# %%
import re
import pandas as pd

chrom_x_idx = clinvar["variants/CHROM"] == 'X'
pathogenic_idx = np.array([x == "Pathogenic" for x in clinvar["variants/CLNSIG"]])
prostate_idx = np.array(["prostate" in x.lower() for x in clinvar["variants/CLNDN"]])

idx_set = chrom_x_idx & pathogenic_idx & prca_idx

pathogenic_df = pd.DataFrame(
    dict([(k, clinvar["variants/" + k][idx_set]) 
    for k in ["CHROM", "POS", "REF", "GENEINFO", "CLNDN", "CLNSIG", "AF_TGP"]])
)
pathogenic_df["ALT"] = clinvar["variants/ALT"][idx_set, 0]

pathogenic_df
# Out:
#    CHROM       POS REF                       GENEINFO  \
# 0      X  66765148   T                         AR:367
# 1      X  66765196   C  AR:367|LOC109504725:109504725
# 2      X  66765463   G                         AR:367
# 3      X  66765802   C                         AR:367
# 4      X  66766013   C                         AR:367
# 5      X  66766051   G                         AR:367
# 6      X  66766163   C                         AR:367
# 7      X  66766183   T                         AR:367
# 8      X  66766196   C                         AR:367
# 9      X  66863125   G                         AR:367
# 10     X  66863132   G                         AR:367
# 11     X  66905875   A                         AR:367
# 12     X  66931301   G                         AR:367
# 13     X  66937326   G                         AR:367
# 14     X  66937330   C                         AR:367
# 15     X  66937337   G                         AR:367
# 16     X  66942818   G                         AR:367
# 17     X  66943543   C                         AR:367
# 18     X  66943552   A                         AR:367
# 19     X  66943553   C                         AR:367
# 20     X  66943628   A                         AR:367
#
#                                                 CLNDN      CLNSIG   AF_TGP  \
# 0   Malignant_tumor_of_prostate|Kennedy_disease|An...  Pathogenic      NaN
# 1                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 2   Malignant_tumor_of_prostate|Androgen_resistanc...  Pathogenic      NaN
# 3            Malignant_tumor_of_prostate|not_provided  Pathogenic      NaN
# 4                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 5                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 6                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 7                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 8                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 9                         Malignant_tumor_of_prostate  Pathogenic      NaN
# 10                        Malignant_tumor_of_prostate  Pathogenic      NaN
# 11  Non-obstructive_azoospermia|Malignant_tumor_of...  Pathogenic      NaN
# 12                                    Prostate_cancer  Pathogenic      NaN
# 13  Malignant_tumor_of_prostate|Prostate_cancer_su...  Pathogenic  0.00053
# 14                        Malignant_tumor_of_prostate  Pathogenic      NaN
# 15        Malignant_tumor_of_prostate|Prostate_cancer  Pathogenic  0.00053
# 16          Malignant_tumor_of_prostate|Hypospadias_1  Pathogenic      NaN
# 17                                    Prostate_cancer  Pathogenic      NaN
# 18                                    Prostate_cancer  Pathogenic      NaN
# 19                                    Prostate_cancer  Pathogenic      NaN
# 20                                    Prostate_cancer  Pathogenic      NaN
#
#      ALT
# 0   TTGC
# 1      T
# 2      A
# 3      T
# 4      T
# 5      C
# 6      G
# 7      C
# 8      T
# 9      T
# 10     C
# 11     G
# 12     A
# 13     T
# 14     G
# 15     A
# 16     A
# 17     T
# 18     G
# 19     G
# 20     G

# %% [markdown]
# There were 21 pathogenic variants to prostate cancer in chromosome X. These variants came from the AR:367 gene.
#
# The AR gene makes the androgen receptor. Androgen receptor binds to androgenic hormones including testosterone. Its functions include being a DNA binding transcription factor that regulates gene expression and also development and maintenance of the male sexual phenotype. According to literature, the androgen receptor is linked with pathogenesis and progression of prostate cancer. An overexpression of AR leads to progression of prostate cancer.

# %% [markdown]
# ## Identifying subjects carrying pathogenic variants

# %% [markdown]
# Now, I will be screening the 1000 genome project to identify subjects carrying prostate cancer pathogenic variants. First, I will shortlist the variants that both appear in the variants identified in the Clinvar database and 1000 genome project. I will be converting vcf file to a zarr file to make handling of large data more manageable.
#
# I will also find the maximum number of alternate alleles across all positions, since this information could be useful when I try to calculate alternate allele frequencies of different alleles.

# %%
import zarr

if "vcf" in dir():
    del vcf

vcf_filename = DATA + "/ALL.chrX.phase3_shapeit2_mvncall_integrated_v1b.20130502.genotypes.vcf.gz"

vcf = allel.read_vcf(str(vcf_filename), ["variants/ID", "variants/numalt"],
                     log=sys.stdout)
# Out:
# [read_vcf] 65536 rows in 3.60s; chunk in 3.60s (18210 rows/s); X:1734128
# [read_vcf] 131072 rows in 6.91s; chunk in 3.31s (19777 rows/s); X:3915040
# [read_vcf] 196608 rows in 9.86s; chunk in 2.95s (22219 rows/s); X:6474138
# [read_vcf] 262144 rows in 12.98s; chunk in 3.12s (21032 rows/s); X:9519142
# [read_vcf] 327680 rows in 16.04s; chunk in 3.06s (21388 rows/s); X:12551848
# [read_vcf] 393216 rows in 19.11s; chunk in 3.07s (21359 rows/s); X:15550284
# [read_vcf] 458752 rows in 22.03s; chunk in 2.92s (22436 rows/s); X:18776831
# [read_vcf] 524288 rows in 24.96s; chunk in 2.93s (22385 rows/s); X:21881750
# [read_vcf] 589824 rows in 28.30s; chunk in 3.34s (19637 rows/s); X:24574486
# [read_vcf] 655360 rows in 31.27s; chunk in 2.98s (22010 rows/s); X:27659891
# [read_vcf] 720896 rows in 34.11s; chunk in 2.84s (23101 rows/s); X:30671296
# [read_vcf] 786432 rows in 37.00s; chunk in 2.89s (22652 rows/s); X:33194562
# [read_vcf] 851968 rows in 40.10s; chunk in 3.10s (21131 rows/s); X:36031556
# [read_vcf] 917504 rows in 43.36s; chunk in 3.25s (20140 rows/s); X:39125534
# [read_vcf] 983040 rows in 46.72s; chunk in 3.36s (19497 rows/s); X:42186473
# [read_vcf] 1048576 rows in 49.65s; chunk in 2.93s (22392 rows/s); X:45309329
# [read_vcf] 1114112 rows in 52.77s; chunk in 3.13s (20964 rows/s); X:48359153
# [read_vcf] 1179648 rows in 56.20s; chunk in 3.42s (19137 rows/s); X:51881411
# [read_vcf] 1245184 rows in 59.09s; chunk in 2.89s (22673 rows/s); X:55705421
# [read_vcf] 1310720 rows in 61.96s; chunk in 2.87s (22809 rows/s); X:57996652
# [read_vcf] 1376256 rows in 64.88s; chunk in 2.91s (22485 rows/s); X:63082608
# [read_vcf] 1441792 rows in 67.70s; chunk in 2.83s (23187 rows/s); X:65358749
# [read_vcf] 1507328 rows in 70.73s; chunk in 3.02s (21668 rows/s); X:67634861
# [read_vcf] 1572864 rows in 73.58s; chunk in 2.86s (22937 rows/s); X:70712278
# [read_vcf] 1638400 rows in 76.43s; chunk in 2.84s (23038 rows/s); X:74091783
# [read_vcf] 1703936 rows in 79.28s; chunk in 2.85s (22982 rows/s); X:76280043
# [read_vcf] 1769472 rows in 82.14s; chunk in 2.86s (22904 rows/s); X:78926545
# [read_vcf] 1835008 rows in 85.45s; chunk in 3.31s (19788 rows/s); X:81422228
# [read_vcf] 1900544 rows in 88.39s; chunk in 2.94s (22277 rows/s); X:83965308
# [read_vcf] 1966080 rows in 91.27s; chunk in 2.87s (22829 rows/s); X:86441870
# [read_vcf] 2031616 rows in 94.21s; chunk in 2.94s (22290 rows/s); X:89012763
# [read_vcf] 2097152 rows in 97.23s; chunk in 3.02s (21676 rows/s); X:91967747
# [read_vcf] 2162688 rows in 100.11s; chunk in 2.88s (22771 rows/s); X:94617360
# [read_vcf] 2228224 rows in 103.02s; chunk in 2.91s (22520 rows/s); X:97514551
# [read_vcf] 2293760 rows in 105.91s; chunk in 2.89s (22655 rows/s); X:100546234
# [read_vcf] 2359296 rows in 108.84s; chunk in 2.93s (22377 rows/s); X:104064469
# [read_vcf] 2424832 rows in 111.68s; chunk in 2.84s (23036 rows/s); X:107375123
# [read_vcf] 2490368 rows in 114.54s; chunk in 2.85s (22969 rows/s); X:110344724
# [read_vcf] 2555904 rows in 117.39s; chunk in 2.86s (22942 rows/s); X:113267805
# [read_vcf] 2621440 rows in 120.28s; chunk in 2.88s (22721 rows/s); X:116181346
# [read_vcf] 2686976 rows in 123.14s; chunk in 2.87s (22852 rows/s); X:118882692
# [read_vcf] 2752512 rows in 125.99s; chunk in 2.85s (23025 rows/s); X:121911362
# [read_vcf] 2818048 rows in 128.90s; chunk in 2.91s (22494 rows/s); X:124928450
# [read_vcf] 2883584 rows in 131.81s; chunk in 2.91s (22535 rows/s); X:127808992
# [read_vcf] 2949120 rows in 134.65s; chunk in 2.84s (23058 rows/s); X:130956155
# [read_vcf] 3014656 rows in 137.51s; chunk in 2.85s (22986 rows/s); X:134318747
# [read_vcf] 3080192 rows in 140.35s; chunk in 2.85s (23018 rows/s); X:137603907
# [read_vcf] 3145728 rows in 143.20s; chunk in 2.85s (23011 rows/s); X:140749939
# [read_vcf] 3211264 rows in 146.06s; chunk in 2.86s (22915 rows/s); X:143421964
# [read_vcf] 3276800 rows in 149.06s; chunk in 3.00s (21851 rows/s); X:146052307
# [read_vcf] 3342336 rows in 151.93s; chunk in 2.87s (22795 rows/s); X:149173075
# [read_vcf] 3407872 rows in 155.09s; chunk in 3.15s (20783 rows/s); X:152165183
# [read_vcf] 3468093 rows in 157.95s; chunk in 2.86s (21077 rows/s)
# [read_vcf] all done (21957 rows/s)

# %%
numalt = vcf['variants/numalt']
max_alt = np.max(numalt)
max_alt
# Out:
# 9

# %%
zarr_file = vcf_filename.replace(".vcf.gz", ".zarr")
if not os.path.exists(zarr_file):
    allel.vcf_to_zarr(str(vcf_filename),
                      str(zarr_file),
                      fields='*', alt_number=max_alt,
                      log=sys.stdout, overwrite=True)
# Out:
# [vcf_to_zarr] 65536 rows in 18.37s; chunk in 18.37s (3567 rows/s); X:1734128
# [vcf_to_zarr] 131072 rows in 35.40s; chunk in 17.03s (3847 rows/s); X:3915040
# [vcf_to_zarr] 196608 rows in 50.55s; chunk in 15.15s (4326 rows/s); X:6474138
# [vcf_to_zarr] 262144 rows in 63.79s; chunk in 13.24s (4949 rows/s); X:9519142
# [vcf_to_zarr] 327680 rows in 76.67s; chunk in 12.88s (5086 rows/s); X:12551848
# [vcf_to_zarr] 393216 rows in 89.81s; chunk in 13.13s (4990 rows/s); X:15550284
# [vcf_to_zarr] 458752 rows in 102.19s; chunk in 12.39s (5290 rows/s); X:18776831
# [vcf_to_zarr] 524288 rows in 114.18s; chunk in 11.99s (5466 rows/s); X:21881750
# [vcf_to_zarr] 589824 rows in 126.26s; chunk in 12.08s (5426 rows/s); X:24574486
# [vcf_to_zarr] 655360 rows in 138.35s; chunk in 12.09s (5418 rows/s); X:27659891
# [vcf_to_zarr] 720896 rows in 150.55s; chunk in 12.20s (5370 rows/s); X:30671296
# [vcf_to_zarr] 786432 rows in 163.66s; chunk in 13.11s (4999 rows/s); X:33194562
# [vcf_to_zarr] 851968 rows in 177.75s; chunk in 14.09s (4652 rows/s); X:36031556
# [vcf_to_zarr] 917504 rows in 191.38s; chunk in 13.63s (4807 rows/s); X:39125534
# [vcf_to_zarr] 983040 rows in 204.88s; chunk in 13.49s (4856 rows/s); X:42186473
# [vcf_to_zarr] 1048576 rows in 219.50s; chunk in 14.62s (4481 rows/s); X:45309329
# [vcf_to_zarr] 1114112 rows in 232.82s; chunk in 13.33s (4917 rows/s); X:48359153
# [vcf_to_zarr] 1179648 rows in 245.89s; chunk in 13.07s (5014 rows/s); X:51881411
# [vcf_to_zarr] 1245184 rows in 259.15s; chunk in 13.26s (4943 rows/s); X:55705421
# [vcf_to_zarr] 1310720 rows in 273.22s; chunk in 14.06s (4659 rows/s); X:57996652
# [vcf_to_zarr] 1376256 rows in 286.04s; chunk in 12.83s (5108 rows/s); X:63082608
# [vcf_to_zarr] 1441792 rows in 298.62s; chunk in 12.58s (5210 rows/s); X:65358749
# [vcf_to_zarr] 1507328 rows in 311.25s; chunk in 12.62s (5191 rows/s); X:67634861
# [vcf_to_zarr] 1572864 rows in 323.59s; chunk in 12.34s (5309 rows/s); X:70712278
# [vcf_to_zarr] 1638400 rows in 336.21s; chunk in 12.62s (5191 rows/s); X:74091783
# [vcf_to_zarr] 1703936 rows in 348.67s; chunk in 12.46s (5261 rows/s); X:76280043
# [vcf_to_zarr] 1769472 rows in 361.05s; chunk in 12.38s (5293 rows/s); X:78926545
# [vcf_to_zarr] 1835008 rows in 373.81s; chunk in 12.76s (5136 rows/s); X:81422228
# [vcf_to_zarr] 1900544 rows in 387.15s; chunk in 13.34s (4912 rows/s); X:83965308
# [vcf_to_zarr] 1966080 rows in 399.99s; chunk in 12.84s (5103 rows/s); X:86441870
# [vcf_to_zarr] 2031616 rows in 412.45s; chunk in 12.46s (5259 rows/s); X:89012763
# [vcf_to_zarr] 2097152 rows in 425.30s; chunk in 12.85s (5100 rows/s); X:91967747
# [vcf_to_zarr] 2162688 rows in 437.85s; chunk in 12.55s (5220 rows/s); X:94617360
# [vcf_to_zarr] 2228224 rows in 450.25s; chunk in 12.40s (5284 rows/s); X:97514551
# [vcf_to_zarr] 2293760 rows in 463.18s; chunk in 12.93s (5068 rows/s); X:100546234
# [vcf_to_zarr] 2359296 rows in 475.96s; chunk in 12.77s (5130 rows/s); X:104064469
# [vcf_to_zarr] 2424832 rows in 488.93s; chunk in 12.97s (5052 rows/s); X:107375123
# [vcf_to_zarr] 2490368 rows in 501.72s; chunk in 12.79s (5124 rows/s); X:110344724
# [vcf_to_zarr] 2555904 rows in 514.26s; chunk in 12.54s (5224 rows/s); X:113267805
# [vcf_to_zarr] 2621440 rows in 526.71s; chunk in 12.44s (5266 rows/s); X:116181346
# [vcf_to_zarr] 2686976 rows in 539.17s; chunk in 12.46s (5258 rows/s); X:118882692
# [vcf_to_zarr] 2752512 rows in 551.53s; chunk in 12.37s (5300 rows/s); X:121911362
# [vcf_to_zarr] 2818048 rows in 563.95s; chunk in 12.41s (5279 rows/s); X:124928450
# [vcf_to_zarr] 2883584 rows in 576.40s; chunk in 12.45s (5263 rows/s); X:127808992
# [vcf_to_zarr] 2949120 rows in 588.82s; chunk in 12.42s (5275 rows/s); X:130956155
# [vcf_to_zarr] 3014656 rows in 601.21s; chunk in 12.39s (5288 rows/s); X:134318747
# [vcf_to_zarr] 3080192 rows in 613.58s; chunk in 12.37s (5299 rows/s); X:137603907
# [vcf_to_zarr] 3145728 rows in 625.91s; chunk in 12.33s (5313 rows/s); X:140749939
# [vcf_to_zarr] 3211264 rows in 639.38s; chunk in 13.47s (4866 rows/s); X:143421964
# [vcf_to_zarr] 3276800 rows in 653.17s; chunk in 13.78s (4754 rows/s); X:146052307
# [vcf_to_zarr] 3342336 rows in 667.36s; chunk in 14.20s (4616 rows/s); X:149173075
# [vcf_to_zarr] 3407872 rows in 682.42s; chunk in 15.06s (4352 rows/s); X:152165183
# [vcf_to_zarr] 3468093 rows in 695.06s; chunk in 12.64s (4765 rows/s)
# [vcf_to_zarr] all done (4985 rows/s)

# %% [markdown]
# Once the VCF file has been converted to Zarr file, I can now create a dataframe extracting the rows that are pathogenic variants of prostate cancer from 1000 genome project Zarr file.

# %%
vcfzarr = zarr.open_group(str(zarr_file), mode="r")

pos_idx = np.where(np.isin(vcfzarr["variants/POS"], pathogenic_df.POS))[0]

vdf =  pd.DataFrame(
    dict([(k, vcfzarr["variants/" + k][pos_idx]) 
    for k in ["CHROM", "POS", "REF"]])
)
vdf["ALT"] = vcfzarr["variants/ALT"][pos_idx, 0]

vdf = vdf.merge(pathogenic_df)

vdf
# Out:
#   CHROM       POS REF ALT GENEINFO  \
# 0     X  66765802   C   T   AR:367
# 1     X  66766163   C   G   AR:367
# 2     X  66937326   G   T   AR:367
# 3     X  66937337   G   A   AR:367
#
#                                                CLNDN      CLNSIG   AF_TGP
# 0           Malignant_tumor_of_prostate|not_provided  Pathogenic      NaN
# 1                        Malignant_tumor_of_prostate  Pathogenic      NaN
# 2  Malignant_tumor_of_prostate|Prostate_cancer_su...  Pathogenic  0.00053
# 3        Malignant_tumor_of_prostate|Prostate_cancer  Pathogenic  0.00053

# %% [markdown]
# There are a total of 4 variants observed in 1000 genome project. Now that we have an idea of which variants appear in 1000 genome project, we can extract subjects with non-homozygous reference genotype to identify subjects carrying pathogenic variants of prostate cancer. In the genotype array, we would be essentially looking for subjects with genotypes that are not 0/0 for female or 0/. for male.

# %%
# reset idx
pos_idx = np.where(np.isin(vcfzarr["variants/POS"], vdf.POS))[0]

gt = allel.GenotypeArray(np.array([vcfzarr["calldata/GT"][i] for i in pos_idx]))

# convert genotype info to pandas dataframe
gt_df = pd.DataFrame(
    gt.to_gt(),
    columns=np.array(vcfzarr["samples"]),
    index="X:" + pd.Series(vcfzarr["variants/POS"]).loc[pos_idx].astype(str)
)

bool_df = (gt_df != b'0/.') & (gt_df != b'0/0')
bool_df.columns.values[bool_df.any(axis=0)]

gt_df[bool_df.columns.values[bool_df.any(axis=0)]]
# Out:
#            HG00321 HG00371 HG01850 HG02031 HG02069 HG02787
# X:66765802  b'0/.'  b'0/.'  b'0/0'  b'0/0'  b'0/0'  b'0/1'
# X:66766163  b'0/.'  b'0/.'  b'0/0'  b'1/0'  b'0/0'  b'0/0'
# X:66937326  b'1/.'  b'1/.'  b'0/0'  b'0/0'  b'0/0'  b'0/0'
# X:66937337  b'0/.'  b'0/.'  b'0/1'  b'0/0'  b'0/1'  b'0/0'

# %% [markdown]
# There are 6 subjects that have variants of interest. Now we can create a new dataframe summarizing genotype information from the provided csv file.

# %%
df = gt_df.loc[:, bool_df.any(axis=0)].melt(ignore_index=False, var_name="subject_id", value_name="genotype")

# remove reference entries
df = df[(df.genotype != b"0/0") & (df.genotype != b"0/.")].reset_index()

# %%
# merge population table to get super population code
meta = pd.read_csv(DATA + "/1kgn_phase3_population.csv")
out = df.merge(meta[["Sample name", "Superpopulation code", "Sex"]], left_on="subject_id", right_on="Sample name")
out = out.rename(columns={
    "index": "variant_of_interest",
    "Sex": "gender",
    "Superpopulation code": "superpopulation_code",
}).drop("Sample name", axis=1)[["subject_id", "gender", "superpopulation_code", "variant_of_interest", "genotype"]]

# %%
out
# Out:
#   subject_id  gender superpopulation_code variant_of_interest genotype
# 0    HG00321    male                  EUR          X:66937326   b'1/.'
# 1    HG00371    male                  EUR          X:66937326   b'1/.'
# 2    HG01850  female                  EAS          X:66937337   b'0/1'
# 3    HG02031  female                  EAS          X:66766163   b'1/0'
# 4    HG02069  female                  EAS          X:66937337   b'0/1'
# 5    HG02787  female                  SAS          X:66765802   b'0/1'

# %% [markdown]
# From the table above, we see that two male subjects had pathogenic variants of prostate cancer. The two subjects are from European subpopulation.
